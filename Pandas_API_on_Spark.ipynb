# %% [markdown]
# ## Pandas API on Spark

# %% [markdown]
# Commonly used by data scientists, pandas is a Python package that provides easy-to-use data structures and data analysis tools for the Python programming language. However, pandas does not scale out to big data. **Pandas API** on Spark fills this gap by providing pandas equivalent APIs that work on Apache Spark. Pandas API on Spark is useful not only for pandas users but also PySpark users, because pandas API on Spark supports many tasks that are **difficult to do with PySpark**, for example plotting data directly from a PySpark DataFrame.
#
# - If you use Pandas but you are not familiar with Spark, you can work with Spark right away, with no learning curve.
#
# - You can have a single codebase for everything: small data and big data. A single machine and distributed machines.
#
# - You can run your Pandas code faster.

# %% [markdown]
# ### Pandas API on Spark is available beginning in Apache Spark 3.2
# ![databricks1](https://github.com/fissehab/Pandas_API_for_PySpark/blob/main/databricks1.PNG?raw=true)
# ![databricks2](https://github.com/fissehab/Pandas_API_for_PySpark/blob/main/databricks2.PNG?raw=true)

# %% [markdown]
# ## Benchmark: Pandas API Vs Dask

# %% [markdown]
# ![comparison with dask](https://www.databricks.com/wp-content/uploads/2021/04/koalas-blog-img-resampled-1.jpg)

# %% [markdown]
# ![with filtering](https://www.databricks.com/wp-content/uploads/2021/04/koalas-blog-img-resampled-2.jpg)

# %%
import pyspark.pandas as ps

# %%
dir(ps)
# Out:
# Out[2]: ['CategoricalIndex',
#  'DataFrame',
#  'DatetimeIndex',
#  'Float64Index',
#  'Index',
#  'Int64Index',
#  'LooseVersion',
#  'MultiIndex',
#  'NamedAgg',
#  'Series',
#  'TaskContext',
#  'TimedeltaIndex',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_auto_patch_pandas',
#  '_auto_patch_spark',
#  '_frame_has_class_getitem',
#  '_series_has_class_getitem',
#  '_typing',
#  'accessors',
#  'base',
#  'broadcast',
#  'categorical',
#  'concat',
#  'config',
#  'data_type_ops',
#  'date_range',
#  'datetimes',
#  'exceptions',
#  'frame',
#  'from_pandas',
#  'generic',
#  'get_dummies',
#  'get_option',
#  'groupby',
#  'indexes',
#  'indexing',
#  'internal',
#  'isna',
#  'isnull',
#  'melt',
#  'merge',
#  'merge_asof',
#  'missing',
#  'ml',
#  'mlflow',
#  'namespace',
#  'notna',
#  'notnull',
#  'option_context',
#  'options',
#  'os',
#  'plot',
#  'pyarrow',
#  'range',
#  'read_clipboard',
#  'read_csv',
#  'read_delta',
#  'read_excel',
#  'read_html',
#  'read_json',
#  'read_orc',
#  'read_parquet',
#  'read_spark_io',
#  'read_sql',
#  'read_sql_query',
#  'read_sql_table',
#  'read_table',
#  'require_minimum_pandas_version',
#  'require_minimum_pyarrow_version',
#  'reset_option',
#  'series',
#  'set_option',
#  'spark',
#  'sql',
#  'sql_formatter',
#  'strings',
#  'sys',
#  'timedelta_range',
#  'to_datetime',
#  'to_numeric',
#  'to_timedelta',
#  'typedef',
#  'usage_logging',
#  'utils',
#  'warnings',
#  'window']

# %%
dir(ps.options)
# Out:
# Out[3]: ['compute.default_index_type',
#  'compute.eager_check',
#  'compute.isin_limit',
#  'compute.max_rows',
#  'compute.ops_on_diff_frames',
#  'compute.ordered_head',
#  'compute.shortcut_limit',
#  'display.max_rows',
#  'plotting.backend',
#  'plotting.max_rows',
#  'plotting.sample_ratio']

# %% [markdown]
# - pandas.core.frame.DataFrame: single machine
#
# - pyspark.pandas.frame.DataFrame: distributed

# %%
import pyspark.pandas as ps
import pandas as pd
import numpy as np

df_ps = ps.read_delta("/mnt/datadrop-test/fw_fish/stream_bronze/budget_file_name_date_oct_1to15_2022/")
type(df_ps)
# Out:
# Out[5]: pyspark.pandas.frame.DataFrame

# %% [markdown]
# [5 reasons to choose Delta format (on Databricks)](https://medium.com/datalex/5-reasons-to-use-delta-lake-format-on-databricks-d9e76cf3e77d)

# %%
df_pd = pd.read_parquet('/dbfs/mnt/datadrop-test/fw_fish/stream_bronze/budget_file_name_date_oct_1to15_2022/')
type(df_pd)
# Out:
# Out[6]: pandas.core.frame.DataFrame

# %%
df_ps_2_pd = df_ps.to_pandas()
type(df_ps_2_pd)
# Out:
# Out[7]: pandas.core.frame.DataFrame

# %%
df_pd_2_ps = ps.from_pandas(df_pd)
type(df_pd_2_ps)
# Out:
# Out[9]: pyspark.pandas.frame.DataFrame

# %% [markdown]
# Note that if you are using multiple machines, when converting a Pandas-on-Spark Dataframe into a Pandas Dataframe, data is transferred from multiple machines to a single one, and vice-versa

# %%
df_spark = df_ps.to_spark()
type(df_spark)
# Out:
# Out[11]: pyspark.sql.dataframe.DataFrame

# %%
df_ps_new = df_spark.pandas_api()
type(df_ps_new)
# Out:
# Out[13]: pyspark.pandas.frame.DataFrame

# %% [markdown]
# ## Pandas API on Spark examples

# %%
df_ps.columns
# Out:
# Out[38]: Index(['advertiser_id', 'advertising_product_type', 'budget',
#        'budget_scope_id', 'budget_scope_type', 'budget_usage_percentage',
#        'dataset_id', 'marketplace_id', 'usage_updated_timestamp',
#        'file_date_time', 'usage_updated_timestamp2', 'file_date_time2',
#        'minutes_diff'],
#       dtype='object')

# %%
df_ps.dtypes
# Out:
# Out[14]: advertiser_id                       object
# advertising_product_type            object
# budget                             float64
# budget_scope_id                     object
# budget_scope_type                   object
# budget_usage_percentage            float64
# dataset_id                          object
# marketplace_id                      object
# usage_updated_timestamp             object
# file_date_time                      object
# usage_updated_timestamp2    datetime64[ns]
# file_date_time2             datetime64[ns]
# minutes_diff                       float64
# dtype: object

# %% [markdown]
# ### Internal type mapping
# The table below shows which NumPy data types are matched to which PySpark data types internally in pandas API on Spark.
#
# ![data mapping](https://github.com/fissehab/Pandas_API_for_PySpark/blob/main/Capture.PNG?raw=true)

# %%
df_ps.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>advertiser_id</th>
#       <th>advertising_product_type</th>
#       <th>budget</th>
#       <th>budget_scope_id</th>
#       <th>budget_scope_type</th>
#       <th>budget_usage_percentage</th>
#       <th>dataset_id</th>
#       <th>marketplace_id</th>
#       <th>usage_updated_timestamp</th>
#       <th>file_date_time</th>
#       <th>usage_updated_timestamp2</th>
#       <th>file_date_time2</th>
#       <th>minutes_diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2965762</th>
#       <td>ENTITY32FCMYHLD5TT5</td>
#       <td>sp</td>
#       <td>389.96</td>
#       <td>146967882456693</td>
#       <td>CAMPAIGN</td>
#       <td>55.26</td>
#       <td>budget-usage</td>
#       <td>ATVPDKIKX0DER</td>
#       <td>2022-10-11T16:25:15Z</td>
#       <td>2022-10-11-16-30-09</td>
#       <td>2022-10-11 16:25:15</td>
#       <td>2022-10-11 16:30:09</td>
#       <td>4.90</td>
#     </tr>
#     <tr>
#       <th>2965763</th>
#       <td>ENTITY5U0BYY2U38HR</td>
#       <td>sp</td>
#       <td>374.40</td>
#       <td>277169250999342</td>
#       <td>CAMPAIGN</td>
#       <td>85.18</td>
#       <td>budget-usage</td>
#       <td>ATVPDKIKX0DER</td>
#       <td>2022-10-11T16:26:02Z</td>
#       <td>2022-10-11-16-30-09</td>
#       <td>2022-10-11 16:26:02</td>
#       <td>2022-10-11 16:30:09</td>
#       <td>4.12</td>
#     </tr>
#     <tr>
#       <th>2965764</th>
#       <td>ENTITY2ZVDWJCGA7N7B</td>
#       <td>sp</td>
#       <td>56.30</td>
#       <td>147940483039430</td>
#       <td>CAMPAIGN</td>
#       <td>8.47</td>
#       <td>budget-usage</td>
#       <td>ATVPDKIKX0DER</td>
#       <td>2022-10-11T16:26:49Z</td>
#       <td>2022-10-11-16-30-09</td>
#       <td>2022-10-11 16:26:49</td>
#       <td>2022-10-11 16:30:09</td>
#       <td>3.33</td>
#     </tr>
#     <tr>
#       <th>2965765</th>
#       <td>ENTITY31HC6VQONPBOD</td>
#       <td>sp</td>
#       <td>7.64</td>
#       <td>43505528567681</td>
#       <td>CAMPAIGN</td>
#       <td>66.23</td>
#       <td>budget-usage</td>
#       <td>ATVPDKIKX0DER</td>
#       <td>2022-10-11T16:27:27Z</td>
#       <td>2022-10-11-16-30-09</td>
#       <td>2022-10-11 16:27:27</td>
#       <td>2022-10-11 16:30:09</td>
#       <td>2.70</td>
#     </tr>
#     <tr>
#       <th>2965766</th>
#       <td>ENTITY1UOBRQ39USYG7</td>
#       <td>sb</td>
#       <td>100.00</td>
#       <td>144290983053228187</td>
#       <td>CAMPAIGN</td>
#       <td>96.31</td>
#       <td>budget-usage</td>
#       <td>A2Q3Y263D00KWC</td>
#       <td>2022-10-11T16:25:29Z</td>
#       <td>2022-10-11-16-30-09</td>
#       <td>2022-10-11 16:25:29</td>
#       <td>2022-10-11 16:30:09</td>
#       <td>4.67</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df_ps[['budget', 'budget_usage_percentage']].describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>budget</th>
#       <th>budget_usage_percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>3.458467e+06</td>
#       <td>3.458467e+06</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>5.513685e+04</td>
#       <td>4.412482e+01</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>2.343872e+07</td>
#       <td>3.005584e+02</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>1.000000e+00</td>
#       <td>0.000000e+00</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>1.655000e+01</td>
#       <td>1.531000e+01</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>5.000000e+01</td>
#       <td>3.695000e+01</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>1.500000e+02</td>
#       <td>6.789000e+01</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>1.000000e+10</td>
#       <td>4.535530e+05</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df_ps.isnull().sum()
# Out:
# Out[7]: advertiser_id                  0
# advertising_product_type    1614
# budget                         0
# budget_scope_id                0
# budget_scope_type              0
# budget_usage_percentage        0
# dataset_id                     0
# marketplace_id                 0
# usage_updated_timestamp        0
# file_date_time                 0
# usage_updated_timestamp2       0
# file_date_time2                0
# minutes_diff                   0
# dtype: int64

# %%
df_ps.marketplace_id.value_counts(normalize=True)
# Out:
# Out[8]: ATVPDKIKX0DER     0.867564
# A2EUQ1WTGCTBG2    0.108485
# A1AM78C64UM0Y8    0.020884
# A2Q3Y263D00KWC    0.003066
# Name: marketplace_id, dtype: float64

# %%
df_ps.advertiser_id.nunique()
# Out:
# Out[6]: 347

# %%
df_ps.marketplace_id.unique()
# Out:
# Out[37]: 0    A1AM78C64UM0Y8
# 1    A2Q3Y263D00KWC
# 2     ATVPDKIKX0DER
# 3    A2EUQ1WTGCTBG2
# Name: marketplace_id, dtype: object

# %%
df_ps.groupby(['advertiser_id']).budget_scope_id.count().head(20)
# Out:
# Out[16]: advertiser_id
# ENTITYMNC7R8USIYO0      1574
# ENTITY24NJD5I0B4993      229
# ENTITY2ENDW3U3WOIVO     3627
# ENTITYFCTZKK8S6F4L      6389
# ENTITY1VPEBRSCE0LIU     1312
# ENTITY2H8KY25F5EHUE    19227
# ENTITY34I5D9IPGCP7Q     3761
# ENTITY3V9Z0J68IEMBU      222
# ENTITYDSK49EZJPS26     19895
# ENTITY1B9CKJJA1CBXB    10563
# A32U15M077H6Z6         33465
# ENTITY13BBG132ZA6AC     1386
# ENTITY1VVK8FT70Q49K     2079
# ENTITY1B3YW5IYOJKZO     2189
# ENTITY1Z2AOJR3WZS3C     4659
# ENTITY39NGZ7JCOM0XF     2993
# ENTITY31Q1I62V7AXFV    20263
# ENTITY14RQ3TMEX6QX9      562
# ENTITY2Q91U4F9Z1Z31     3341
# ENTITY23JNRRL6QJIRJ    45724
# Name: budget_scope_id, dtype: int64

# %%
df_ps[['advertiser_id','marketplace_id']].drop_duplicates().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>advertiser_id</th>
#       <th>marketplace_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>116602</th>
#       <td>A19EHJRIAHY95T</td>
#       <td>ATVPDKIKX0DER</td>
#     </tr>
#     <tr>
#       <th>25646</th>
#       <td>A1F3R2IX95F1NB</td>
#       <td>ATVPDKIKX0DER</td>
#     </tr>
#     <tr>
#       <th>842</th>
#       <td>A1FLHWKA43KGDZ</td>
#       <td>ATVPDKIKX0DER</td>
#     </tr>
#     <tr>
#       <th>14750</th>
#       <td>ENTITY12Y9WGZMKEYGU</td>
#       <td>ATVPDKIKX0DER</td>
#     </tr>
#     <tr>
#       <th>385</th>
#       <td>ENTITY189I4QBHE1O2H</td>
#       <td>ATVPDKIKX0DER</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df_ps.groupby('advertiser_id')['budget'].mean().head(20)
# Out:
# Out[17]: advertiser_id
# ENTITYMNC7R8USIYO0     1260.605972
# ENTITY24NJD5I0B4993      26.214672
# ENTITY202M9MT6I1UOS      19.389535
# ENTITYFCTZKK8S6F4L       22.063356
# ENTITY1VPEBRSCE0LIU     202.265244
# ENTITY2ENDW3U3WOIVO    1150.184778
# ENTITY2H8KY25F5EHUE     114.249697
# ENTITY34I5D9IPGCP7Q      36.001776
# ENTITY3V9Z0J68IEMBU      31.097297
# ENTITYDSK49EZJPS26       37.160141
# ENTITY1B9CKJJA1CBXB      58.903210
# A32U15M077H6Z6           23.624925
# ENTITY13BBG132ZA6AC       2.116162
# ENTITY1VVK8FT70Q49K     719.323300
# ENTITY1B3YW5IYOJKZO      47.211055
# ENTITY1Z2AOJR3WZS3C      82.796255
# ENTITY39NGZ7JCOM0XF     121.699766
# ENTITY31Q1I62V7AXFV      25.977936
# ENTITY14RQ3TMEX6QX9     204.170819
# ENTITY2Q91U4F9Z1Z31      72.292592
# Name: budget, dtype: float64

# %%
filtered = df_ps[df_ps.marketplace_id != 'ATVPDKIKX0DER']
filtered.shape
# Out:
# Out[9]: (458024, 13)

# %%
filtered = df_ps[df_ps.advertiser_id.str.contains("B9CK")]
filtered.shape
# Out:
# Out[10]: (10563, 13)

# %%
filtered = df_ps[df_ps.usage_updated_timestamp2.dt.month==9]
set(filtered.usage_updated_timestamp2.dt.month.to_numpy())
# Out:
# Out[13]: {9}

# %% [markdown]
# ### transform and apply

# %%
df_ps.groupby('advertiser_id')['budget'].apply(np.cumsum).head(20)
# Out:
# Out[18]: 1349943       1.0
# 1490533      11.0
# 1491718      21.0
# 1492792      31.0
# 1495030      32.0
# 1496199      33.0
# 1496686      34.0
# 1501303     234.0
# 1503179     434.0
# 1503187    1234.0
# 1504808    1235.0
# 1508970    1635.0
# 1510845    1835.0
# 1512388    2235.0
# 1512556    2435.0
# 1518923    2445.0
# 1529482    2645.0
# 1536944    2655.0
# 1547177    2665.0
# 1547179    2675.0
# Name: budget, dtype: float64

# %% [markdown]
# ### Plotting with Pandas API on Spark

# %%
df_ps.groupby('marketplace_id')['budget'].mean().reset_index().plot.pie(y='budget')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="e6d0a33f-7a2c-4e61-a9e9-8c145c04267f" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6d0a33f-7a2c-4e61-a9e9-8c145c04267f")) {                    Plotly.newPlot(                        "e6d0a33f-7a2c-4e61-a9e9-8c145c04267f",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"index=%{label}<br>budget=%{value}<extra></extra>","labels":[0,1,2,3],"legendgroup":"","name":"","showlegend":true,"values":[162.73458532938275,150.04474304573316,63541.25196910686,63.27530460323086],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker ...

# %%
df_ps.groupby('budget_scope_id')['budget'].mean().sort_values(ascending = False).head(10).plot.barh()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="500328bc-3fcd-423f-aa6a-c23aac78f5ca" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("500328bc-3fcd-423f-aa6a-c23aac78f5ca")) {                    Plotly.newPlot(                        "500328bc-3fcd-423f-aa6a-c23aac78f5ca",                        [{"alignmentgroup":"True","hovertemplate":"variable=budget<br>value=%{x}<br>budget_scope_id=%{y}<extra></extra>","legendgroup":"budget","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"budget","offsetgroup":"budget","orientation":"h","showlegend":true,"textposition":"auto","x":[1250000764.14125,1052631733.4568421,952381446.1200002,869566220.6191304,666668635.3293332,645162318.1503226,526316095.3526316,526315946.5473684,500002766.21124995,416666937.9895833],"xaxis":"x","y":["5029613385477","91118105522091","65217807404126","49121868081799","212734571173877","246055996363757","171424809917204","3942516106869","16393579106612","104378075417904"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinew ...

# %%
df_ps['hour'] = df_ps['usage_updated_timestamp2'].dt.hour
df_ps.groupby('hour')['budget'].mean().plot.bar()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="df75061e-a30a-4488-82dc-5b765d021c59" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df75061e-a30a-4488-82dc-5b765d021c59")) {                    Plotly.newPlot(                        "df75061e-a30a-4488-82dc-5b765d021c59",                        [{"alignmentgroup":"True","hovertemplate":"variable=budget<br>hour=%{x}<br>value=%{y}<extra></extra>","legendgroup":"budget","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"budget","offsetgroup":"budget","orientation":"v","showlegend":true,"textposition":"auto","x":[19,0,22,17,1,12,13,18,14,15,20,16,2,21,23,7,6,3,11,9,10,8,4,5],"xaxis":"x","y":[209.6237510485251,224.34319419757205,223.62653430439042,188.9141245075796,211.9677527526586,175.3134394404025,163.42185107431945,195.21621753686384,175.84624150073662,181.85657538631938,207.80728821871983,186.77889190208782,220.2794878574763,210.56996295671308,214.9365197786026,323.1292363365572,234.1551538269983,231.0325659881536,145.35666797067833,132.92389259542372,140.58858127673574,146.06240942405282,1009162.8232691541,1608518.5756339177],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{ ...

# %% [markdown]
# ##### You can see the methods supported using **dir**

# %%
dir(df_ps.groupby('hour')['budget'])
# Out:
# Out[15]: ['__abstractmethods__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__orig_bases__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_agg_columns',
#  '_agg_columns_scols',
#  '_agg_columns_selected',
#  '_apply_series_op',
#  '_as_index',
#  '_build',
#  '_cleanup_and_return',
#  '_column_labels_to_exclude',
#  '_dropna',
#  '_groupkeys',
#  '_groupkeys_scols',
#  '_is_protocol',
#  '_limit',
#  '_make_pandas_df_builder_func',
#  '_prepare_group_map_apply',
#  '_psdf',
#  '_psser',
#  '_reduce_for_stat_function',
#  '_resolve_grouping',
#  '_resolve_grouping_from_diff_dataframes',
#  '_spark_group_map_apply',
#  '_spark_groupby',
#  'agg',
#  'aggregate',
#  'all',
#  'any',
#  'apply',
#  'backfill',
#  'bfill',
#  'count',
#  'cumcount',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'diff',
#  'expanding',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'get_group',
#  'head',
#  'idxmax',
#  'idxmin',
#  'last',
#  'max',
#  'mean',
#  'median',
#  'min',
#  'nlargest',
#  'nsmallest',
#  'nunique',
#  'pad',
#  'rank',
#  'rolling',
#  'shift',
#  'size',
#  'std',
#  'sum',
#  'tail',
#  'transform',
#  'unique',
#  'value_counts',
#  'var']

# %% [markdown]
# #### References
#
# [Pandas API on Spark user guide](https://spark.apache.org/docs/latest/api/python/user_guide/pandas_on_spark/index.html)
#
# [Pandas API on Spark reference](https://spark.apache.org/docs/latest/api/python/reference/pyspark.pandas/index.html)
